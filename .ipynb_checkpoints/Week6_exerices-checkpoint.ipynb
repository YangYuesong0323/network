# %% [markdown]
# ## Part A

# %%
import nltk
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,10)

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text7.concordance("decrease")
# Out:
# Displaying 3 of 3 matches:
# erage circulation of 4,393,237 , a decrease of 7.3 % . Newsweek 's circulation
#  0 *T*-1 `` We 've seen a dramatic decrease in demand for wines from the '40s
# one must fundamentally increase or decrease his ownership in widgets *-1 to ma

# %%
text7.similar("increase")
# Out:
# issue drop company share idea exchange trading improve reduce
# specialist departure board of group this unit year problem research
# information

# %%
text7.common_contexts(["great", "good"])
# Out:
# a_deal as_a

# %%
text7.dispersion_plot(["increase","good","decrease"])

# %%
## vocab variety

# %%
fdist1 = FreqDist(text2)

# %%
fdist1.plot(75, cumulative=True)
plt.show()

# %%
sorted([x for x in set(text5) if x != "" and x[0] == 'b'])
# Out:
# ['b',
#  'b-day',
#  'b/c',
#  'b4',
#  'babay',
#  'babble',
#  'babblein',
#  'babe',
#  'babes',
#  'babi',
#  'babies',
#  'babiess',
#  'baby',
#  'babycakeses',
#  'bachelorette',
#  'back',
#  'backatchya',
#  'backfrontsidewaysandallaroundtheworld',
#  'backroom',
#  'backup',
#  'bacl',
#  'bad',
#  'bag',
#  'bagel',
#  'bagels',
#  'bahahahaa',
#  'bak',
#  'baked',
#  'balad',
#  'balance',
#  'balck',
#  'ball',
#  'ballin',
#  'balls',
#  'ban',
#  'band',
#  'bandito',
#  'bandsaw',
#  'banjoes',
#  'banned',
#  'baord',
#  'bar',
#  'barbie',
#  'bare',
#  'barely',
#  'bares',
#  'barfights',
#  'barks',
#  'barn',
#  'barrel',
#  'base',
#  'bases',
#  'basically',
#  'basket',
#  'battery',
#  'bay',
#  'bbbbbyyyyyyyeeeeeeeee',
#  'bbiam',
#  'bbl',
#  'bbs',
#  'bc',
#  'be',
#  'beach',
#  'beachhhh',
#  'beam',
#  'beams',
#  'beanbag',
#  'beans',
#  'bear',
#  'bears',
#  'beat',
#  'beaten',
#  'beatles',
#  'beats',
#  'beattles',
#  'beautiful',
# ...

# %%
text9.index('sunset')
# Out:
# 629

# %%
" ".join(text9[621:644])
# Out:
# 'THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .'

# %%
len(sorted(set(w.lower() for w in text1)))
# Out:
# 17231

# %%
len(sorted(w.lower() for w in set(text1)))
# Out:
# 19317

# %%
fdist1 = sorted([x for x in list(FreqDist(text4).items()) if len(x[0]) == 4],
                key = lambda x : x[1], reverse=True)
fdist1
# Out:
# [('that', 1748),
#  ('have', 1008),
#  ('will', 909),
#  ('with', 906),
#  ('this', 720),
#  ('from', 540),
#  ('been', 488),
#  ('must', 365),
#  ('upon', 365),
#  ('they', 352),
#  ('them', 327),
#  ('more', 309),
#  ('than', 240),
#  ('only', 237),
#  ('time', 215),
#  ('such', 192),
#  ('free', 184),
#  ('most', 170),
#  ('when', 170),
#  ('made', 156),
#  ('what', 150),
#  ('make', 143),
#  ('good', 141),
#  ('were', 141),
#  ('life', 139),
#  ('well', 134),
#  ('laws', 129),
#  ('into', 128),
#  ('best', 120),
#  ('duty', 118),
#  ('just', 118),
#  ('work', 118),
#  ('hope', 116),
#  ('This', 115),
#  ('your', 114),
#  ('each', 113),
#  ('both', 104),
#  ('know', 103),
#  ('They', 103),
#  ('long', 100),
#  ('much', 98),
#  ('many', 97),
#  ('part', 96),
#  ('same', 92),
#  ('some', 91),
#  ('over', 87),
#  ('ever', 87),
#  ('less', 82),
#  ('high', 77),
#  ('come', 76),
#  ('need', 75),
#  ('land', 72),
#  ('then', 71),
#  ('home', 71),
#  ('here', 70),
#  ('find', 68),
# ...

# %%
for word in text5[:]:
    if word.isupper():
        print(word)
# Out:
# :P
# PART
# NICK
# U7
# U7
# ACTION
# U121
# JOIN
# U59
# JOIN
# PART
# U7
# U121
# PART
# PART
# PART
# JOIN
# PART
# U115
# JOIN
# PART
# PART
# JOIN
# JOIN
# JOIN
# PART
# I
# I
# I
# U115
# U129
# U115
# PART
# JOIN
# JOIN
# U116
# JOIN
# U68
# PART
# PART
# JOIN
# U121
# B
# U30
# JOIN
# PART
# JOIN
# U133
# JOIN
# JOIN
# PART
# JOIN
# PART
# ACTION
# U115
# ACTION
# U68
# JOIN
# JOIN
# U126
# PART
# PART
# U126
# JOIN
# U30
# JOIN
# I
# U64
# U139
# U44
# PART
# PART
# JOIN
# JOIN
# U68
# PART
# JOIN
# U139
# PART
# JOIN
# U138
# HAHAHA
# U139
# U44
# U139
# U126
# PART
# U121
# ACTION
# U121
# JOIN
# U139
# U20
# U68
# U136
# PM
# U139
# U101
# I
# U83
# U20
# :P
# PART
# JOIN
# A
# U30
# U6
# U7
# U115
# ACTION
# U136
# PM
# I
# U7
# U139
# U121
# I
# PART
# I
# PART
# DIRTY
# U141
# PM
# PART
# JOIN
# U6
# PART
# U6
# U115
# ACTION
# U6
# U115
# ACTION
# U6
# I
# U121
# U121
# PART
# U6
# U121
# JOIN
# U7
# JOIN
# U121
# JOIN
# ALL
# U121
# PM
# PART
# I
# I
# JOIN
# PART
# ...

# %%
sum([len(w) for w in text1]) / len([w for w in text1])
# Out:
# 3.830411128023649

# %%
def vocab_size(text):
    return len(set(text))/len(text)

# %%
def percent(word, text):
    count = 0
    for x in word:
        if x == word:
            count += 1
    return count / len(text)

# %% [markdown]
# ## Part 2

# %%
from nltk.corpus import gutenberg

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
emma = nltk.corpus.gutenberg.words('austen-emma.txt')

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
macbeth_sentences = gutenberg.sents('shakespeare-macbeth.txt')
macbeth_sentences
# Out:
# [['[', 'The', 'Tragedie', 'of', 'Macbeth', 'by', 'William', 'Shakespeare', '1603', ']'], ['Actus', 'Primus', '.'], ...]
